# %% [markdown]
# # Spotify
#
# Leer todos los csv de una carpeta y cargarlos en un único dataframe de pandas.
#
# Este enfoque sirve cuando los CSV tienen la misma estructura de columnas pero solo cambia las fechas.
#
# https://www.kaggle.com/datasets/cnic92/spotify-past-decades-songs-50s10s

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os


import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_csv('/Users/pablozepedadiez/Downloads/Modulo_2 2/dataset.csv')
df

#Esta función abre el documento csv
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df.shape
# Esta funcion me marca la cantidad de filas y columnas que contiene
# Out:
# (114000, 21)

# %%
df.head()
# Nos enseña las primeras 5 filas del dataset
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df = df.rename(columns={'popularity': 'hits'})
# Esta funcion cambia el nombre de la columna popularity a hits

# %%
df.head()
#Revisamos que se hayan hecho los cambios correctamente
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  hits  duration_ms  explicit  danceability  \
# 0                      Comedy    73       230666     False         0.676
# 1            Ghost - Acoustic    55       149610     False         0.420
# ...

# %%
df.info()
#Resumen completo de dataframe, cantidad y tipos de variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   hits              114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df.describe()
#Arroja un analisis descriptivo de todo el dataset como estadistica
# Out:
#           Unnamed: 0           hits   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %% [markdown]
# ## Tratamiento de nulos
#
# Se detectan 16 valores nulos en la columna top genre

# %%
df.isnull().sum()
# Indica la cantidad de valores nulos para cada variable
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# hits                0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#top_genre_mode = df['top genre'].mode().iloc[0]
# Este no tiene sentido porque no existen datos nulos
# otra opción es rellenar los nulos con la moda
# df['top genre'].fillna(top_genre_mode, inplace=True)
#top_genre_mode

# %%
# no hay duplicados
df.duplicated().sum()
# Este arrojaria listas, nombres o cosas duplicadas
# Out:
# np.int64(0)

# %%
# borrar columnas
df.drop(columns=['Unnamed: 0'], inplace=True)
# Esta funcion borra la columna que indiquemos

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  hits  duration_ms  explicit  danceability  \
# 0                      Comedy    73       230666     False         0.676
# 1            Ghost - Acoustic    55       149610     False         0.420
# 2              To Begin Again    57       210826     False         0.438
# ...

# %% [markdown]
# ## Ordenar por año

# %%
df.sort_values(['tempo'], inplace=True)
df.reset_index(drop=True, inplace=True) # rehacer el índice
df.head()
#Esta funcion ordena de menor a mayor Tempo
# Out:
#                  track_id                                            artists  \
# 0  1WCpq85hZdiov2DN39Sqfd  Deep Sleep Hair Dryers;Hair Dryer Collection;H...
# 1  0bDFsdF1BdtWzjqE2Vfxvl                             White Noise Meditation
# 2  2mRc9bJZTUoMjWzbGwGBGy                                           Granular
# 3  0jZmx4t0Fg4SJxJj0jnAdU                           White Noise Sleep Sounds
# 4  4YukH0BeXhJmcCmz2BBRke                             Baby Sleep White Noise
#
#                         album_name  \
# 0                      Hair Dryers
# 1  Background Noise For Baby Sleep
# 2             Pink Noise For Sleep
# 3             Soothing White Noise
# 4    Relaxing Loopable White Noise
#
#                                     track_name  hits  duration_ms  explicit  \
# 0  Hair Dryer Sound 19 - Loopable With No Fade    34        84000     False
# 1    Clean White Noise - Loopable with No Fade    36        73442     False
# ...

# %%
df.tail()
# Este te arroja los ultimos datos del dataset
# Out:
#                       track_id                   artists  \
# 113995  2mvXJ9JNoxuX50uT2mLHhN             Hugh Masekela
# 113996  1FUCKL0Q7UZBz3J1eUjSbJ  Billboard Baby Lullabies
# 113997  3Qq52P28qQHcFXZeoQmNSm  Billboard Baby Lullabies
# 113998  25G1w3E4OMrovtPE5F510g                Portishead
# 113999  55ROr3cl3yi4YRBgfpDy1d                 J.J. Cale
#
#                                    album_name              track_name  hits  \
# 113995                    Best Afrobeat Tunes                  Makoti     0
# 113996  Lullaby Renditions of Winnie the Pooh  Heffalumps and Woozles    20
# 113997  Lullaby Renditions of Winnie the Pooh        Hip Hip Pooh Rah    20
# 113998                             Portishead                Undenied    46
# 113999                              Naturally         Call The Doctor    59
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 113995       274933     False         0.469   0.824    8   -10.785     1
# ...

# %% [markdown]
# ## Visualización

# %%
df['duration_ms'].hist()
# Esta funcion grafica la duracion de todas las canciones
# Out:
# <Axes: >

# %%
df['duration_ms'].plot()
# Saca la duracion promedio de todos los datos
# Out:
# <Axes: >

# %%
df['duration_ms'].plot(kind='box')
#Arroja un diagrama sobre los datos de duracion
# Out:
# <Axes: >

# %% [markdown]
# ## Mostrar géneros y artistas más repetidos

# %%
df['duration_ms'].mode()
#Saca la moda de la variable
# Out:
# 0    162897
# Name: duration_ms, dtype: int64

# %%
serie = df['duration_ms'].value_counts()
pd.DataFrame(serie).head(10)
#Hace el conteo de todos los valores que se repiten y con el pd saca los 10 mas repetidos
# Out:
#              count
# duration_ms
# 162897         146
# 180000         104
# 192000          91
# 240000          84
# 118840          76
# 172342          75
# 227520          71
# 131733          70
# 243057          66
# 175986          63

# %%
serie = df['artists'].value_counts()
pd.DataFrame(serie).head(10)
#Arroja el conteo de artistas mas repetidos y el top 10
# Out:
#                  count
# artists
# The Beatles        279
# George Jones       271
# Stevie Wonder      236
# Linkin Park        224
# Ella Fitzgerald    222
# Prateek Kuhad      217
# Feid               202
# Chuck Berry        190
# Håkan Hellström    183
# OneRepublic        181

# %% [markdown]
# ## Mostrar la canción más popular y la menos popular
#
# Columna pop

# %%
df.head(5)

#Arroja los 5 valores con menor tempo
# Out:
#                  track_id                                            artists  \
# 0  1WCpq85hZdiov2DN39Sqfd  Deep Sleep Hair Dryers;Hair Dryer Collection;H...
# 1  0bDFsdF1BdtWzjqE2Vfxvl                             White Noise Meditation
# 2  2mRc9bJZTUoMjWzbGwGBGy                                           Granular
# 3  0jZmx4t0Fg4SJxJj0jnAdU                           White Noise Sleep Sounds
# 4  4YukH0BeXhJmcCmz2BBRke                             Baby Sleep White Noise
#
#                         album_name  \
# 0                      Hair Dryers
# 1  Background Noise For Baby Sleep
# 2             Pink Noise For Sleep
# 3             Soothing White Noise
# 4    Relaxing Loopable White Noise
#
#                                     track_name  hits  duration_ms  explicit  \
# 0  Hair Dryer Sound 19 - Loopable With No Fade    34        84000     False
# 1    Clean White Noise - Loopable with No Fade    36        73442     False
# ...

# %%
df.tail(5)
#Arroja los 5 valores con mayor tempo
# Out:
#                       track_id                   artists  \
# 113995  2mvXJ9JNoxuX50uT2mLHhN             Hugh Masekela
# 113996  1FUCKL0Q7UZBz3J1eUjSbJ  Billboard Baby Lullabies
# 113997  3Qq52P28qQHcFXZeoQmNSm  Billboard Baby Lullabies
# 113998  25G1w3E4OMrovtPE5F510g                Portishead
# 113999  55ROr3cl3yi4YRBgfpDy1d                 J.J. Cale
#
#                                    album_name              track_name  hits  \
# 113995                    Best Afrobeat Tunes                  Makoti     0
# 113996  Lullaby Renditions of Winnie the Pooh  Heffalumps and Woozles    20
# 113997  Lullaby Renditions of Winnie the Pooh        Hip Hip Pooh Rah    20
# 113998                             Portishead                Undenied    46
# 113999                              Naturally         Call The Doctor    59
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 113995       274933     False         0.469   0.824    8   -10.785     1
# ...

# %%
# puntuación más alta en popularidad
df['hits'].max()
# Out:
# np.int64(100)

# %%
# posición de la canción más popular
df['hits'].idxmax()
# Out:
# 74315

# %%
df.loc[df['hits'].idxmax()]
#Te arroja la informacion del hits mas popular
# Out:
# track_id               3nqQXoyQOWXiESFLlDF1hG
# artists                  Sam Smith;Kim Petras
# album_name          Unholy (feat. Kim Petras)
# track_name          Unholy (feat. Kim Petras)
# hits                                      100
# duration_ms                            156943
# explicit                                False
# danceability                            0.714
# energy                                  0.472
# key                                         2
# loudness                               -7.375
# mode                                        1
# speechiness                            0.0864
# acousticness                            0.013
# instrumentalness                     0.000005
# liveness                                0.266
# valence                                 0.238
# tempo                                 131.121
# time_signature                              4
# track_genre                               pop
# Name: 74315, dtype: object

# %%
pd.DataFrame(df.loc[df['hits'].idxmin()])
#Te arroja la informacion del hits menos popular
# Out:
#                                       36
# track_id          38Ogh3rsHba83kXx13gbKs
# artists                       Leila Bela
# album_name                   Angra Manyu
# track_name                           V-4
# hits                                   0
# duration_ms                        13386
# explicit                           False
# danceability                         0.0
# energy                             0.224
# key                                   11
# loudness                         -22.196
# mode                                   1
# speechiness                          0.0
# acousticness                        0.97
# instrumentalness                     0.0
# liveness                           0.907
# valence                              0.0
# tempo                                0.0
# time_signature                         0
# track_genre                      iranian

# %% [markdown]
# ## Mostrar la canción más popular por año

# %%
df['tempo'].value_counts()
#Arroja el dato del conteo de variables por tempo
# Out:
# tempo
# 0.000      157
# 151.925    146
# 95.004      95
# 87.925      76
# 130.594     76
#           ...
# 124.206      1
# 124.204      1
# 124.196      1
# 124.193      1
# 243.372      1
# Name: count, Length: 45653, dtype: int64

# %%
df.groupby('tempo')['hits'].idxmax()
#Agrupa los hits por el tempo que tienen
# Out:
# tempo
# 0.000         153
# 30.200        157
# 30.322        158
# 31.834        159
# 34.262        160
#             ...
# 220.081    113993
# 220.084    113996
# 220.525    113997
# 222.605    113998
# 243.372    113999
# Name: hits, Length: 45653, dtype: int64

# %%
index = df.groupby('tempo')['hits'].idxmax()
df.loc[index]
#Genera un nuevo indice unicamente con los datos de la agrupacion anterior
# Out:
#                       track_id                                        artists  \
# 153     2bRKxuH1o7pTmb1y4GfdEc  White Noise Baby Sleep;White Noise for Babies
# 157     6VwRN2gV7xF8pPxwry5Nvz                         White Noise for Babies
# 158     6JINDc6wg5bOpqIZul2c8u                            Justnormal;frumhere
# 159     47U6UBCMwwXkf7saw2VAW3                                 Terrence Woods
# 160     05yTnAWnD2ho0bS7wbY6xs                                  The Jamborees
# ...                        ...                                            ...
# 113993  6w1T511GDmnHWF1EqqZm2y                                  Hugh Masekela
# 113996  1FUCKL0Q7UZBz3J1eUjSbJ                       Billboard Baby Lullabies
# 113997  3Qq52P28qQHcFXZeoQmNSm                       Billboard Baby Lullabies
# 113998  25G1w3E4OMrovtPE5F510g                                     Portishead
# 113999  55ROr3cl3yi4YRBgfpDy1d                                      J.J. Cale
#
# ...

# %% [markdown]
# ## Muestra los tipos de generos musicales

# %%
df['track_genre'].unique()
#Muestra todos los generos que existen
# Out:
# array(['sleep', 'world-music', 'iranian', 'guitar', 'show-tunes',
#        'romance', 'jazz', 'ambient', 'opera', 'study', 'kids',
#        'psych-rock', 'comedy', 'classical', 'trip-hop', 'anime', 'german',
#        'grindcore', 'new-age', 'piano', 'chill', 'songwriter',
#        'singer-songwriter', 'folk', 'blues', 'hard-rock', 'disney',
#        'indian', 'idm', 'garage', 'punk-rock', 'country', 'soul', 'funk',
#        'hardcore', 'children', 'brazil', 'j-dance', 'indie-pop', 'indie',
#        'disco', 'french', 'groove', 'tango', 'r-n-b', 'mpb', 'grunge',
#        'black-metal', 'industrial', 'rockabilly', 'british', 'gospel',
#        'alt-rock', 'alternative', 'emo', 'honky-tonk', 'turkish',
#        'acoustic', 'pop', 'afrobeat', 'mandopop', 'sad', 'cantopop',
#        'club', 'death-metal', 'swedish', 'synth-pop', 'metal', 'j-pop',
#        'party', 'rock-n-roll', 'heavy-metal', 'pop-film', 'spanish',
#        'electro', 'samba', 'metalcore', 'forro', 'goth', 'dancehall',
# ...

# %%
df['track_genre'].value_counts()
#Muestra la cantidad de valores por cada genero
# Out:
# track_genre
# sleep         1000
# latin         1000
# hip-hop       1000
# punk          1000
# rock          1000
#               ...
# hardcore      1000
# funk          1000
# soul          1000
# country       1000
# deep-house    1000
# Name: count, Length: 114, dtype: int64

# %%
# ver columnas
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'hits',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
# extraer la posición de una columna
position = df.columns.get_loc('album_name') + 1  # posición 3 + 1
position
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'hits',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
df.head()
#Imprime la tabla ya ajustada con los datos trabajados
# Out:
#                  track_id                                            artists  \
# 0  1WCpq85hZdiov2DN39Sqfd  Deep Sleep Hair Dryers;Hair Dryer Collection;H...
# 1  0bDFsdF1BdtWzjqE2Vfxvl                             White Noise Meditation
# 2  2mRc9bJZTUoMjWzbGwGBGy                                           Granular
# 3  0jZmx4t0Fg4SJxJj0jnAdU                           White Noise Sleep Sounds
# 4  4YukH0BeXhJmcCmz2BBRke                             Baby Sleep White Noise
#
#                         album_name  \
# 0                      Hair Dryers
# 1  Background Noise For Baby Sleep
# 2             Pink Noise For Sleep
# 3             Soothing White Noise
# 4    Relaxing Loopable White Noise
#
#                                     track_name  hits  duration_ms  explicit  \
# 0  Hair Dryer Sound 19 - Loopable With No Fade    34        84000     False
# 1    Clean White Noise - Loopable with No Fade    36        73442     False
# ...

# %%
index = df.groupby('track_genre')['artists'].idxmax()
df.loc[index]
#Agrupo a todos los artistas del mismo genero
# Out:
#                      track_id                                       artists  \
# 80385  1FHCU1rDAeaPsBW9byjJ0Q                               krissy & ericka
# 46833  7KDiI2Q1pJnZoTpGl7r50f                                    cacique'97
# 53462  5gFfoZxgMHgMiArpO4Balz                                   İnsan Mıyız
# 53783  6G8xvLFNkXy3HM5EbQI6c8                                 lovelytheband
# 34047  42DSWZ06VzGVzuoRwZEHHe  Ólafur Arnalds;Reykjavík Recording Orchestra
# ...                       ...                                           ...
# 56776  74oc8wSuilCIueLaqNOi3B                    Øostil;Juan Hansen;Massano
# 89616  6po0MzJTuLfaVLGKQUthGw                        tyDi;Kundo;London Thor
# 48911  5r2PGWAJvLHdMXxjZJ1m1H                              Zero 7;Tina Dico
# 9750   5QDT9tNIvFqmw1SEv7qhAd                                      Şekersiz
# 130    6XsYJ0dwT2hRzp0Qles78F                             Колыбельная-земля
#
# ...
